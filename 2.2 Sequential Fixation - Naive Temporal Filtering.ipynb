# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy  as np
import matplotlib.pyplot as plt
import skimage.io
from scipy.io import loadmat
import numpy as np

from saliency.model import  IttyKoch
from saliency.data import load_video
from saliency import utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X, y = load_video(0)
X.shape, y.shape
# Out:
# ((387, 576, 720, 3), (2, 387, 18))

# %%
Xm = X.mean(axis=0)
dX = (X - Xm).mean(axis=-1)
dX.shape
# Out:
# (387, 576, 720)

# %%
plt.imshow(dX[100])
plt.title("Temporal filtering")
plt.axis("off")
plt.show()

# %%
yy, xx = utils.argmax2d(dX)

plt.imshow(X.mean(axis=0)/255.)
plt.plot(y[0,:,0], y[1,:,0], label="GT")
plt.plot(xx,yy, label="PRED")
plt.legend()
plt.title("Predicted trajectory")
plt.axis("off")
plt.show()
