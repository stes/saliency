# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy  as np
import matplotlib.pyplot as plt
import skimage.io
from scipy.io import loadmat
import numpy as np

from saliency.model import  IttyKoch
from saliency.data import load_video

# %%
X, y = load_video(1)
X.shape, y.shape
# Out:
# ((300, 576, 720, 3), (2, 300, 19))

# %%
import h5py

with

# %%
Xm = X.mean(axis=0)
dX = (X - Xm).mean(axis=-1)
dX.shape
# Out:
# (387, 576, 720)

# %%
plt.imshow(dX[100])

# %%
plt.imshow(X.mean(axis=0)/255.)
plt.plot(y[0,:,0], y[1,:,0], label="GT")
plt.plot(yy,xx, label="PRED")
plt.legend()

# %%
model = IttyKoch(n_jobs=8)

S = model.predict(X)
# Out:
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# ...

# %%
sal     = np.stack([s[0] for s in S], axis=0)
sal.shape
# Out:
# (387, 64, 80)

# %%
plt.imshow(sal[0])

# %%
p = sal.reshape(sal.shape[0],-1)
i = np.arange(p.shape[1])
max_idx = np.stack(np.random.choice(np.arange(p.shape[1]), size=(1), p=p[i]/p[i].sum()) for i in range(len(p))) #.argmax(1)

#max_idx = np.stack(p[i].argmax() for i in range(len(p))) #.argmax(1)

max_idx.shape

maxpos_vect = np.column_stack(np.unravel_index(max_idx, sal[0,:,:].shape))
#xx, yy = maxpos_vect.T

maxpos_vect = maxpos_vect.reshape(maxpos_vect.shape[0], 2, -1)
print(maxpos_vect.shape)
# Out:
# (384, 2, 1)

# %%
plt.plot(maxpos_vect[...,1,0],maxpos_vect[...,0,0], label="PRED")
